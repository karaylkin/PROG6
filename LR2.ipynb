# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Задание 1

# %%
print(f"Мужчин: {data['Sex'].value_counts()['male']}, Женщин: {data['Sex'].value_counts()['female']}")
# Out:
# Мужчин: 577, Женщин: 314

# %% [markdown]
# Задание 2

# %%
print(f"Cherbourg: {data['Embarked'].value_counts()['C']}, Queenstown: {data['Embarked'].value_counts()['Q']}, Southampton: {data['Embarked'].value_counts()['S']}")
# Out:
# Cherbourg: 168, Queenstown: 77, Southampton: 644

# %% [markdown]
# Задание 3

# %%
people = data.iloc[-1]['PassengerId']
print(f"{round((data['Survived'].value_counts()[0] / people * 100), 2)} % умерло, Всего умерло: {data['Survived'].value_counts()[0]}")
# Out:
# 61.62 % умерло, Всего умерло: 549

# %% [markdown]
# Задание 4

# %%
print(f"{round(((data['Pclass'] == 1).sum() / people * 100), 2)} % в первом классе")
print(f"{round(((data['Pclass'] == 2).sum() / people * 100), 2)} % во втором классе")
print(f"{round(((data['Pclass'] == 3).sum() / people * 100), 2)} % в третьем классе")
# Out:
# 24.24 % в первом классе
# 20.65 % во втором классе
# 55.11 % в третьем классе

# %% [markdown]
# Задание 5

# %%
spouses_children = data[['SibSp', 'Parch']]
spouses_children.corr(method='pearson')
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.414838
# Parch  0.414838  1.000000

# %% [markdown]
# Задание 6

# %% [markdown]
# Корреляция между возрастом и параметром Survived

# %%
age_survived = data[['Age', 'Survived']]
age_survived.corr(method='pearson')
# Out:
#                Age  Survived
# Age       1.000000 -0.077221
# Survived -0.077221  1.000000

# %% [markdown]
# Корреляция между полом человека и параметром Survived

# %%
data['SexInt'] = data['Sex'].map({"male": 0, "female": 1})

sex_survived = data[['SexInt', 'Survived']]
sex_survived.corr(method='pearson')
# Out:
#             SexInt  Survived
# SexInt    1.000000  0.543351
# Survived  0.543351  1.000000

# %% [markdown]
# Корреляция между классом, в котором пассажир ехал, и параметром Survived

# %%
pclass_survived = data[['Pclass', 'Survived']]
pclass_survived.corr(method='pearson')
# Out:
#             Pclass  Survived
# Pclass    1.000000 -0.338481
# Survived -0.338481  1.000000

# %% [markdown]
# Задание 7

# %%
print(f"Средний возраст пассажиров: {round(data['Age'].mean(), 1)} лет")
print(f"Медиана возраста: {data['Age'].median()} лет")
print(f"Максимальный возраст: {data['Age'].max()} лет")
print(f"Минимальный возраст: {data['Age'].min()} лет")
# Out:
# Средний возраст пассажиров: 29.7 лет
# Медиана возраста: 28.0 лет
# Максимальный возраст: 80.0 лет
# Минимальный возраст: 0.42 лет

# %% [markdown]
# Задание 8

# %%
print(f"Средняя стоимость билета: {round(data['Fare'].mean(), 3)} долларов")
print(f"Медианная стоимость билета: {data['Fare'].median()} долларов")
print(f"Самая высокая цена билета: {data['Fare'].max()} долларов")
print(f"Самая низкая цена билета: {data['Fare'].min()} долларов")
# Out:
# Средняя стоимость билета: 32.204 долларов
# Медианная стоимость билета: 14.4542 долларов
# Самая высокая цена билета: 512.3292 долларов
# Самая низкая цена билета: 0.0 долларов

# %% [markdown]
# Задание 9

# %%
male_names = data.loc[data['Sex'] == 'male', 'Name']

def extract_first_name(full_name):
    try:
        return full_name.split(', ')[1].split('. ')[1].split(' ')[0]
    except IndexError:
        return None

male_first_names = male_names.apply(extract_first_name)

most_common_male_name = male_first_names.mode()[0]
print(f" Самое популярное мужское имя: {most_common_male_name}")
# Out:
#  Самое популярное мужское имя: William

# %% [markdown]
# Задание 10

# %%
male_names_above_15 = data.query("Sex == 'male' and Age > 15")['Name']
female_names_above_15 = data.query("Sex == 'female' and Age > 15")['Name']

def extract_first_name(full_name):
    try:
        name_part = full_name.split(', ')[1].split('. ')[1]
        if '(' in name_part and ')' in name_part:
            name_in_brackets = name_part.split('(')[1].split(')')[0]
            return name_in_brackets.split(' ')[0]
        return name_part.split(' ')[0]
    except IndexError:
        return None

male_first_names_above_15 = male_names_above_15.apply(extract_first_name).dropna()
female_first_names_above_15 = female_names_above_15.apply(extract_first_name).dropna()

most_common_male = male_first_names_above_15.mode()[0]
most_common_female = female_first_names_above_15.mode()[0]

print(f"Самое популярное мужское имя (возраст > 15): {most_common_male}")
print(f"Самое популярное женское имя (возраст > 15): {most_common_female}")
# Out:
# Самое популярное мужское имя (возраст > 15): William
# Самое популярное женское имя (возраст > 15): Anna
